# %%
#Data Frame
import pandas

#NLP libraries
## Import nltk and dependcies
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
from nltk.tag import StanfordPOSTagger # For french language
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

#Extracting Named entity from article
from bs4 import BeautifulSoup
import requests
import re

##Import spacy for named Entity
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
# Out:
# [nltk_data] Downloading package punkt to /home/keberger/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/keberger/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/keberger/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /home/keberger/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
def preprocesss_and_tag(txt):
    txt = nltk.word_tokenize(txt)
    txt = nltk.pos_tag(txt)
    return txt

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
#hbr : what boards needs to know : https://hbr.org/2019/05/what-boards-need-to-know-about-ai
url = "https://hbr.org/2019/05/what-boards-need-to-know-about-ai"
text = url_to_string(url)
article = nlp(text)
len(article.ents)
# Out:
# 66

# %%
#There are 66 entities in the article and they are represented as 10 unique labels:
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 27,
#          'PERSON': 16,
#          'WORK_OF_ART': 1,
#          'DATE': 4,
#          'GPE': 4,
#          'CARDINAL': 7,
#          'EVENT': 1,
#          'PERCENT': 2,
#          'LANGUAGE': 1,
#          'LAW': 1,
#          'PRODUCT': 1,
#          'NORP': 1})

# %%
#The following are three most frequent tokens.
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('ML', 4), ('AI', 3), ('Douglas Merrill', 2)]

# %%
#Let’s randomly select one sentence to learn more.
sentences = [x for x in article.sents]
print(sentences)
# Out:
# [          What Boards Need to Know About AI                                                                                                      , 2/3 Free Articles, leftRemaining  , Register for more  , |  Subscribe + Save!, Subscribe Sign, In CLEAR SUGGESTED TOPICS Explore HBR, The Latest, The Magazine, Most Popular Podcasts Video Store Webinars Newsletters Popular Topics, Managing, Yourself Leadership Strategy Managing Teams Gender Innovation Work-life, Balance All Topics, For Subscribers, The Big Idea Visual Library Reading Lists Case, Selections Subscribe My Account My Library, Topic Feeds Purchases Account Settings Email, Preferences Log Out, Sign, In Subscribe The Latest Podcasts Video, The Magazine Store Webinars Newsletters, All Topics, The Big Idea Visual Library Reading Lists Case Selections, My Library Account Settings Log Out Sign, In Your Cart, Your Shopping Cart is empty., Visit Our Store Guest User  , Subscriber My Library Topic Feeds Purchases Account Settings Email Preferences Log Out      , Reading List Reading Lists Boards, What Boards Need to Know About, AI Douglas Merrill, May 24, 2019  , Summary Full Text  , Save  Share  , Comment  , Text Size  , Print Loading..., Executive Summary, The questions boards are going to have to ask themselves with regard to artificial intelligence are similar to those they would ask in the face of any large opportunity investment: Why are we spending all this money?, What’s the economic benefit?, How does it impact our people and our long-term competitiveness., Answering these questions requires expertise in technology., But you can’t just simply add a tech expert to the board and count on him or her to keep the rest of the board up to speed. , Boards shouldn’t be intimidated by AI., Members don’t need to have degrees in computer engineering to understand the technology behind AI,, just like they don’t need to be CPAs to understand the company’s balance sheet. , When evaluating if a project is right for their company, boards should feel confident enough to say when something doesn’t make sense.              , C. J. Burton/Getty Images       Being a board member is a hard job — ask anyone who has ever been one., Company directors have to understand the nature of the business, review documents, engage in meaningful conversation with CEOs, and give feedback while still maintaining positive relationships with management., These are all hard things to balance., But, normally, boards don’t have to get involved with individual operational projects, especially technical ones., In fact, a majority of boards have very few members who are comfortable with advanced technology, and this generally has little impact on the company., This is about to change, thanks to machine learning and artificial intelligence., More than half of technology executives in the 2019 Gartner CIO Survey say they intend to employ AI before the end of 2020, up from 14% today., If you’re moving too slowly, a competitor could use AI to put you out of business., But if you move too quickly, you risk taking an approach the company doesn’t truly know how to manage., In a recent report by NewVantage Partners, 75% of companies cited fear of disruption from data-driven digital competitors as the top reason they’re investing., The questions boards are going to have to ask themselves are similar to those they would ask in the face of any large opportunity investment: Why are we spending all this money?, What’s the economic benefit?, How does it impact our people and our long-term competitiveness?  , Insight Center                  Interacting with AI            Sponsored by Qlik                     , How humans and machines will work together.                    , Answering these questions requires expertise in technology., But you can’t, just add a tech expert to the board and count on him or her to keep the rest of the board up to speed., Having served in that role, I have found it to be at best a useful half-step., Re ...

# %%
#Let’s run displacy.render to generate the raw markup.
displacy.render(nlp(str(sentences)), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">[          What Boards Need to Know About AI                                                                                                      ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2/3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Free Articles, leftRemaining  ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Register
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for more  , |  Subscribe + Save!,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Subscribe Sign
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , In CLEAR SUGGESTED TOPICS Explore
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     HBR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , The Latest,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     The Magazine, Most Popular Podcasts Video Store
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Webinars Newsletters Popular Topics,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Managing, Yourself Leadership Strategy Managing Teams Gender Innovation Work-life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Balance All Topics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , For
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Subscribers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     The Big Idea Visual Library Reading Lists Case
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Selections Subscribe My Account My Library, Topic Feeds Purchases Account Settings Email, Preferences Log Out,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Sign
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , In Subscribe The Latest Podcasts Video, The Magazine Store Webinars Newsletters,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     All Topics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     The Big Idea Visual Library Reading Lists Case Selections
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , My
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Library Account Settings Log Out Sign
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , In Your Cart, Your Shopping Cart is empty., Visit Our Store
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Guest User
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Subscriber My Library Topic Feeds Purchases Account Settings Email Preferences Log Out      , Reading List Reading Lists
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Boards
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , What
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Boards Need
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  to Know About, AI
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Douglas Merrill
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     May 24, 2019
#     <span style

# %%
#Using spaCy’s built-in displaCy visualizer, here’s what the above sentence and its dependencies look like:
displacy.render(nlp(str(sentences[1:5])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6cdf19cec52947d4a26dd634d0baafb2-0" class="displacy" width="1850" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">2/3</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Free</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Articles,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">leftRemaining</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650"> ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Register</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">more</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130"> ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">|</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">Subscribe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">+</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">Save!]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6cdf19cec52947d4a26dd634d0baafb2-0-0" stroke-width="2px" d="M70,242.0 C70,2.0 770.0,2.0 770.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6cdf19cec52947d4a26dd634d0baafb2-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,244.0 L62,232.0 78,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6cdf19cec52947d4a26dd634d0baafb2-0-1" stroke-width="2px" d="M190,242.0 C190,122.0 400.0,122.0 400.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6cdf19cec52947d4a26dd634d0baafb2-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,244.0 L182,232.0 198,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6cdf19cec52947d4a26dd634d0baafb2-0-2" stroke-width="2px" d="M310,242.0 C310,182.0 395.0,182.0 395.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6cdf19cec52947d4a26dd634d0baafb2-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,244.0 L302,232.0 318,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6cdf19cec52947d4a26dd634d0baafb2-0-3" stroke-width="2px" d="M430,242.0 C430,62.0 765.0,62.0 765.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6cdf19cec52947d4a26dd634d0baafb2-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,244.0 L422,232.0 438,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6cdf19cec52947d4a26dd634d0baafb2-0-4" stroke-width="2px" d="M550,242.0 C550,122.0 760.0,122.0 760.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6cdf19cec52947d4a26dd634d0baafb2-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,244.0 L542,232.0 558,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6cdf19cec52947d4a26dd634d0baafb2-0-5" stroke-width="2px" d="M550,242.0 C550,182.0 635.0,182.0 635.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6cdf19cec52947d4a26dd634d0baafb2-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M635.0,244.0 L643.0,232.0 627.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6cdf19cec52947d4a26dd634d0baafb2-0-6" stroke-width="2px" d="M790,242.0 C790,182.0 875.0,182.0 875.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6cdf19cec52947d4a26dd634d0baafb2-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-ar

# %%
#Next, we verbatim, extract part-of-speech and lemmatize this sentence.
[(x.orth_,x.pos_, x.lemma_) for x in [y for y in nlp(str(sentences))if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('         ', 'SPACE', '         '),
#  ('Boards', 'PROPN', 'Boards'),
#  ('Need', 'VERB', 'need'),
#  ('Know', 'VERB', 'know'),
#  ('AI', 'PROPN', 'AI'),
#  ('                                                                                                     ',
#   'SPACE',
#   '                                                                                                     '),
#  ('2/3', 'NUM', '2/3'),
#  ('Free', 'PROPN', 'Free'),
#  ('Articles', 'PROPN', 'Articles'),
#  ('leftRemaining', 'NOUN', 'leftremaining'),
#  (' ', 'SPACE', ' '),
#  ('Register', 'PROPN', 'Register'),
#  (' ', 'SPACE', ' '),
#  ('|', 'PROPN', '|'),
#  (' ', 'SPACE', ' '),
#  ('Subscribe', 'PROPN', 'Subscribe'),
#  ('+', 'CCONJ', '+'),
#  ('Save', 'VERB', 'save'),
#  ('Subscribe', 'PROPN', 'Subscribe'),
#  ('Sign', 'PROPN', 'Sign'),
#  ('CLEAR', 'PROPN', 'CLEAR'),
#  ('SUGGESTED', 'VERB', 'suggest'),
#  ('TOPICS', 'PROPN', 'TOPICS'),
#  ('Explore', 'PROPN', 'Explore'),
#  ('HBR', 'PROPN', 'HBR'),
#  ('Latest', 'ADJ', 'late'),
#  ('Magazine', 'PROPN', 'Magazine'),
#  ('Popular', 'PROPN', 'Popular'),
#  ('Podcasts', 'PROPN', 'Podcasts'),
#  ('Video', 'PROPN', 'Video'),
#  ('Store', 'PROPN', 'Store'),
#  ('Webinars', 'VERB', 'webinar'),
#  ('Newsletters', 'PROPN', 'Newsletters'),
#  ('Popular', 'PROPN', 'Popular'),
#  ('Topics', 'PROPN', 'Topics'),
#  ('Managing', 'PROPN', 'Managing'),
#  ('Leadership', 'PROPN', 'Leadership'),
#  ('Strategy', 'PROPN', 'Strategy'),
#  ('Managing', 'PROPN', 'Managing'),
#  ('Teams', 'PROPN', 'Teams'),
#  ('Gender', 'PROPN', 'Gender'),
#  ('Innovation', 'PROPN', 'Innovation'),
#  ('Work', 'NOUN', 'work'),
#  ('life', 'NOUN', 'life'),
#  ('Balance', 'PROPN', 'Balance'),
#  ('Topics', 'PROPN', 'Topics'),
#  ('Subscribers', 'PROPN', 'Subscribers'),
#  ('Big', 'PROPN', 'Big'),
#  ('Idea', 'PROPN', 'Idea'),
#  ('Visual', 'PROPN', 'Visual'),
#  ('Library', 'PROPN', 'Library'),
#  ('Reading', 'PROPN', 'Reading'),
#  ('Lists', 'PROPN', 'Lists'),
#  ('Case', 'PROPN', 'Case'),
#  ('Selections', 'PROPN', 'Selections'),
#  ('Subscribe', 'PROPN', 'Subscribe'),
#  ('Account', 'NOUN', 'account'),
#  ('Library', 'PROPN', 'Library'),
#  ('Topic', 'PROPN', 'Topic'),
#  ('Feeds', 'PROPN', 'Feeds'),
#  ('Purchases', 'PROPN', 'Purchases'),
#  ('Account', 'PROPN', 'Account'),
#  ('Settings', 'PROPN', 'Settings'),
#  ('Email', 'PROPN', 'Email'),
#  ('Preferences', 'PROPN', 'Preferences'),
#  ('Log', 'PROPN', 'Log'),
#  ('Sign', 'PROPN', 'Sign'),
#  ('Subscribe', 'PROPN', 'Subscribe'),
#  ('Latest', 'PROPN', 'Latest'),
#  ('Podcasts', 'PROPN', 'Podcasts'),
#  ('Video', 'PROPN', 'Video'),
#  ('Magazine', 'PROPN', 'Magazine'),
#  ('Store', 'PROPN', 'Store'),
#  ('Webinars', 'PROPN', 'Webinars'),
#  ('Newsletters', 'PROPN', 'Newsletters'),
#  ('Topics', 'PROPN', 'Topics'),
#  ('Big', 'PROPN', 'Big'),
#  ('Idea', 'PROPN', 'Idea'),
#  ('Visual', 'PROPN', 'Visual'),
#  ('Library', 'PROPN', 'Library'),
#  ('Reading', 'PROPN', 'Reading'),
#  ('Lists', 'PROPN', 'Lists'),
#  ('Case', 'PROPN', 'Case'),
#  ('Selections', 'PROPN', 'Selections'),
#  ('Library', 'PROPN', 'Library'),
#  ('Account', 'PROPN', 'Account'),
#  ('Settings', 'PROPN', 'Settings'),
#  ('Log', 'PROPN', 'Log'),
#  ('Sign', 'NOUN', 'sign'),
#  ('Cart', 'PROPN', 'Cart'),
#  ('Shopping', 'NOUN', 'shopping'),
#  ('Cart', 'PROPN', 'Cart'),
#  ('Visit', 'VERB', 'visit'),
#  ('Store', 'PROPN', 'Store'),
#  ('Guest', 'PROPN', 'Guest'),
#  ('User', 'PROPN', 'User'),
#  (' ', 'SPACE', ' '),
#  ('Subscriber', 'PROPN', 'Subscriber'),
#  ('Library', 'PROPN', 'Library'),
#  ('Topic', 'NOUN', 'topic'),
#  ('Feeds', 'PROPN', 'Feeds'),
#  ('Purchases', 'PROPN', 'Purchases'),
#  ('Account', 'PROPN', 'Account'),
#  ('Settings', 'NOUN', 'setting'),
#  ('Email', 'PROPN', 'Email'),
#  ('Preferences', 'PROPN', 'Preferences'),
#  ('Log', 'PROPN', 'Log'),
#  ('     ', 'SPACE', '     '),
#  ('Reading', 'VERB', 'read'),
#  ('List', 'NOUN', 'list'),
#  ('Reading', 'VERB', 'read'),
#  ('Lists', 'PROPN', 'Lists'),
#  ('Boards', 'PROPN', 'Boards'),
#  ('Boards', 'PROPN', 'Boards'),
#  ('Need', 'VERB', 'need'),
#  ('Know', 'VERB', 'know'),
#  ('AI', 'PROPN', 'AI'),
#  ('Douglas', 'PROPN', 'Douglas'),
#  ('Merrill', 'PROPN', 'Merrill'),
#  ('24', 'NUM', '24'),
#  ('2019', 'NUM', '2019'),
#  (' ', 'SPACE', ' '),
#  ('Summary', 'PROPN', 'Summary'),
#  ('Text', 'PROPN', 'Text'),
#  (' ', 'SPACE', ' '),
#  ('Save', 'PROPN', 'Save'),
#  (' ', 'SPACE', ' '),
#  ('Share', 'PROPN', 'Share'),
#  (' ', 'SPACE', ' '),
#  ('Comment', 'PROPN', 'Comment'),
#  (' ', 'SPACE', ' '),
#  ('Text', 'PROPN', 'Text'),
#  ('Size', 'PROPN', 'Size'),
#  (' ', 'SPACE', ' '),
#  ('Print', 'PROPN', 'Print'),
#  ('Loading', 'PROPN', 'Loading'),
#  ('Executive', 'PROPN', 'Executive'),
#  ('Summary', 'PROPN', 'Summary'),
#  ('questions', 'NOUN', 'question'),
#  ('boards', 'NOUN', 'board'),
#  ('going', 'VERB', 'go'),
#  ('ask', 'VERB', 'ask'),
#  ('regard', 'NOUN', 'regard'),
#  ('artificial', 'ADJ', 'artificial'),
#  ('intelligence', 'NOUN', 'intelligence'),
#  ('similar', 'ADJ', 'similar'),
#  ('ask', 'VERB', 'ask'),
#  ('face', 'NOUN', 'face'),
#  ('large', 'ADJ', 'large'),
#  ('opportunity', 'NOUN', 'opportunity'),
#  ('investment', 'NOUN', 'investment'),
#  ('spending', 'VERB', 'spend'),
#  ('money', 'NOUN', 'money'),
#  ('’s', 'PROPN', '’s'),
#  ('economic', 'ADJ', 'economic'),
#  ('benefit', 'NOUN', 'benefit'),
#  ('impact', 'VERB', 'impact'),
#  ('people', 'NOUN', 'people'),
#  ('long', 'ADJ', 'long'),
#  ('term', 'NOUN', 'term'),
#  ('competitiveness', 'NOUN', 'competitiveness'),
#  ('Answering', 'VERB', 'answer'),
#  ('questions', 'NOUN', 'question'),
#  ('requires', 'VERB', 'require'),
#  ('expertise', 'NOUN', 'expertise'),
#  ('technology', 'NOUN', 'technology'),
#  ('n’t', 'ADV', 'not'),
#  ('simply', 'ADV', 'simply'),
#  ('add', 'VERB', 'add'),
#  ('tech', 'NOUN', 'tech'),
#  ('expert', 'NOUN', 'expert'),
#  ('board', 'NOUN', 'board'),
#  ('count', 'VERB', 'count'),
#  ('rest', 'NOUN', 'rest'),
#  ('board', 'NOUN', 'board'),
#  ('speed', 'NOUN', 'speed'),
#  ('\xa0', 'SPACE', '  '),
#  ('Boards', 'PROPN', 'Boards'),
#  ('n’t', 'ADV', 'not'),
#  ('intimidated', 'VERB', 'intimidate'),
#  ('AI', 'PROPN', 'AI'),
#  ('.', 'PROPN', '.'),
#  ('Members', 'NOUN', 'member'),
#  ('n’t', 'ADV', 'not'),
#  ('need', 'VERB', 'need'),
#  ('degrees', 'NOUN', 'degree'),
#  ('computer', 'NOUN', 'computer'),
#  ('engineering', 'NOUN', 'engineering'),
#  ('understand', 'VERB', 'understand'),
#  ('technology', 'NOUN', 'technology'),
#  ('AI', 'PROPN', 'AI'),
#  ('like', 'ADP', 'like'),
#  ('n’t', 'ADV', 'not'),
#  ('need', 'VERB', 'need'),
#  ('CPAs', 'NOUN', 'cpa'),
#  ('understand', 'VERB', 'understand'),
#  ('company', 'NOUN', 'company'),
#  ('’s', 'PROPN', '’s'),
#  ('balance', 'NOUN', 'balance'),
#  ('sheet', 'NOUN', 'sheet'),
#  ('\xa0', 'SPACE', '  '),
#  ('evaluating', 'VERB', 'evaluate'),
#  ('project', 'NOUN', 'project'),
#  ('right', 'ADJ', 'right'),
#  ('company', 'NOUN', 'company'),
#  ('boards', 'NOUN', 'board'),
#  ('feel', 'VERB', 'feel'),
#  ('confident', 'ADJ', 'confident'),
#  ('n’t', 'ADV', 'not'),
#  ('sense', 'NOUN', 'sense'),
#  ('             ', 'SPACE', '             '),
#  ('C.', 'PROPN', 'C.'),
#  ('J.', 'PROPN', 'J.'),
#  ('Burton', 'PROPN', 'Burton'),
#  ('/', 'SYM', '/'),
#  ('Getty', 'PROPN', 'Getty'),
#  ('Images', 'PROPN', 'Images'),
#  ('      ', 'SPACE', '      '),
#  ('board', 'NOUN', 'board'),
#  ('member', 'NOUN', 'member'),
#  ('hard', 'ADJ', 'hard'),
#  ('job', 'NOUN', 'job'),
#  ('ask', 'VERB', 'ask'),
#  ('Company', 'NOUN', 'company'),
#  ('directors', 'NOUN', 'director'),
#  ('understand', 'VERB', 'understand'),
#  ('nature', 'NOUN', 'nature'),
#  ('business', 'NOUN', 'business'),
#  ('review', 'VERB', 'review'),
#  ('documents', 'NOUN', 'document'),
#  ('engage', 'VERB', 'engage'),
#  ('meaningful', 'ADJ', 'meaningful'),
#  ('conversation', 'NOUN', 'conversation'),
#  ('CEOs', 'NOUN', 'ceo'),
#  ('feedback', 'NOUN', 'feedback'),
#  ('maintaining', 'VERB', 'maintain'),
#  ('positive', 'ADJ', 'positive'),
#  ('relationships', 'NOUN', 'relationship'),
#  ('management', 'NOUN', 'management'),
#  ('hard', 'ADJ', 'hard'),
#  ('things', 'NOUN', 'thing'),
#  ('balance', 'VERB', 'balance'),
#  ('normally', 'ADV', 'normally'),
#  ('boards', 'NOUN', 'board'),
#  ('n’t', 'ADV', 'not'),
#  ('involved', 'VERB', 'involve'),
#  ('individual', 'ADJ', 'individual'),
#  ('operational', 'ADJ', 'operational'),
#  ('projects', 'NOUN', 'project'),
#  ('especially', 'ADV', 'especially'),
#  ('technical', 'ADJ', 'technical'),
#  ('ones', 'NOUN', 'one'),
#  ('fact', 'NOUN', 'fact'),
#  ('majority', 'NOUN', 'majority'),
#  ('boards', 'NOUN', 'board'),
#  ('members', 'NOUN', 'member'),
#  ('comfortable', 'ADJ', 'comfortable'),
#  ('advanced', 'ADJ', 'advanced'),
#  ('technology', 'NOUN', 'technology'),
#  ('generally', 'ADV', 'generally'),
#  ('little', 'ADJ', 'little'),
#  ('impact', 'NOUN', 'impact'),
#  ('company', 'NOUN', 'company'),
#  ('change', 'VERB', 'change'),
#  ('thanks', 'NOUN', 'thank'),
#  ('machine', 'NOUN', 'machine'),
#  ('learning', 'NOUN', 'learning'),
#  ('artificial', 'ADJ', 'artificial'),
#  ('intelligence', 'NOUN', 'intelligence'),
#  ('half', 'NOUN', 'half'),
#  ('technology', 'NOUN', 'technology'),
#  ('executives', 'NOUN', 'executive'),
#  ('2019', 'NUM', '2019'),
#  ('Gartner', 'PROPN', 'Gartner'),
#  ('CIO', 'PROPN', 'CIO'),
#  ('Survey', 'PROPN', 'Survey'),
#  ('intend', 'VERB', 'intend'),
#  ('employ', 'VERB', 'employ'),
#  ('AI', 'PROPN', 'AI'),
#  ('end', 'NOUN', 'end'),
#  ('2020', 'NUM', '2020'),
#  ('14', 'NUM', '14'),
#  ('%', 'NOUN', '%'),
#  ('today', 'NOUN', 'today'),
#  ('’re', 'VERB', 'be'),
#  ('moving', 'VERB', 'move'),
#  ('slowly', 'ADV', 'slowly'),
#  ('competitor', 'NOUN', 'competitor'),
#  ('use', 'VERB', 'use'),
#  ('AI', 'PROPN', 'AI'),
#  ('business', 'NOUN', 'business'),
#  ('quickly', 'ADV', 'quickly'),
#  ('risk', 'VERB', 'risk'),
#  ('taking', 'VERB', 'take'),
#  ('approach', 'NOUN', 'approach'),
#  ('company', 'NOUN', 'company'),
#  ('n’t', 'ADV', 'not'),
#  ('truly', 'ADV', 'truly'),
#  ('know', 'VERB', 'know'),
#  ('manage', 'VERB', 'manage'),
#  ('recent', 'ADJ', 'recent'),
#  ('report', 'NOUN', 'report'),
#  ('NewVantage', 'PROPN', 'NewVantage'),
#  ('Partners', 'PROPN', 'Partners'),
#  ('75', 'NUM', '75'),
#  ('%', 'NOUN', '%'),
#  ('companies', 'NOUN', 'company'),
#  ('cited', 'VERB', 'cite'),
#  ('fear', 'NOUN', 'fear'),
#  ('disruption', 'NOUN', 'disruption'),
#  ('data', 'NOUN', 'datum'),
#  ('driven', 'VERB', 'drive'),
#  ('digital', 'ADJ', 'digital'),
#  ('competitors', 'NOUN', 'competitor'),
#  ('reason', 'NOUN', 'reason'),
#  ('’re', 'VERB', 'be'),
#  ('investing', 'VERB', 'invest'),
#  ('questions', 'NOUN', 'question'),
#  ('boards', 'NOUN', 'board'),
#  ('going', 'VERB', 'go'),
#  ('ask', 'VERB', 'ask'),
#  ('similar', 'ADJ', 'similar'),
#  ('ask', 'VERB', 'ask'),
#  ('face', 'NOUN', 'face'),
#  ('large', 'ADJ', 'large'),
#  ('opportunity', 'NOUN', 'opportunity'),
#  ('investment', 'NOUN', 'investment'),
#  ('spending', 'VERB', 'spend'),
#  ('money', 'NOUN', 'money'),
#  ('’s', 'PROPN', '’s'),
#  ('economic', 'ADJ', 'economic'),
#  ('benefit', 'NOUN', 'benefit'),
#  ('impact', 'VERB', 'impact'),
#  ('people', 'NOUN', 'people'),
#  ('long', 'ADJ', 'long'),
#  ('term', 'NOUN', 'term'),
#  ('competitiveness', 'NOUN', 'competitiveness'),
#  (' ', 'SPACE', ' '),
#  ('Insight', 'PROPN', 'Insight'),
#  ('Center', 'PROPN', 'Center'),
#  ('                 ', 'SPACE', '                 '),
#  ('Interacting', 'VERB', 'interact'),
#  ('AI', 'PROPN', 'AI'),
#  ('           ', 'SPACE', '           '),
#  ('Sponsored', 'PROPN', 'Sponsored'),
#  ('Qlik', 'PROPN', 'Qlik'),
#  ('                    ', 'SPACE', '                    '),
#  ('humans', 'NOUN', 'human'),
#  ('machines', 'NOUN', 'machine'),
#  ('work', 'VERB', 'work'),
#  ('                   ', 'SPACE', '                   '),
#  ('Answering', 'VERB', 'answer'),
#  ('questions', 'NOUN', 'question'),
#  ('requires', 'VERB', 'require'),
#  ('expertise', 'NOUN', 'expertise'),
#  ('technology', 'NOUN', 'technology'),
#  ('n’t', 'ADV', 'not'),
#  ('add', 'VERB', 'add'),
#  ('tech', 'NOUN', 'tech'),
#  ('expert', 'NOUN', 'expert'),
#  ('board', 'NOUN', 'board'),
#  ('count', 'VERB', 'count'),
#  ('rest', 'NOUN', 'rest'),
#  ('board', 'NOUN', 'board'),
#  ('speed', 'NOUN', 'speed'),
#  ('Having', 'VERB', 'have'),
#  ('served', 'VERB', 'serve'),
#  ('role', 'NOUN', 'role'),
#  ('found', 'VERB', 'find'),
#  ('best', 'ADJ', 'good'),
#  ('useful', 'ADJ', 'useful'),
#  ('half', 'NOUN', 'half'),
#  ('step', 'NOUN', 'step'),
#  ('Relying', 'VERB', 'rely'),
#  ('single', 'ADJ', 'single'),
#  ('techie', 'NOUN', 'techie'),
#  ('replacement', 'NOUN', 'replacement'),
#  ('having', 'VERB', 'have'),
#  ('board', 'NOUN', 'board'),
#  ('mastering', 'VERB', 'master'),
#  ('basic', 'ADJ', 'basic'),
#  ('understanding', 'NOUN', 'understanding'),
#  ('AI', 'PROPN', 'AI'),
#  ('disruptive', 'ADJ', 'disruptive'),
#  ('potential', 'NOUN', 'potential'),
#  ('board', 'NOUN', 'board'),
#  ('’s', 'PROPN', '’s'),
#  ('comfort', 'NOUN', 'comfort'),
#  ('level', 'NOUN', 'level'),
#  ('going', 'VERB', 'go'),
#  ('differ', 'VERB', 'differ'),
#  ('depending', 'VERB', 'depend'),
#  ('industry', 'NOUN', 'industry'),
#  ('Manufacturers', 'PROPN', 'Manufacturers'),
#  ('understand', 'VERB', 'understand'),
#  ('robots', 'NOUN', 'robot'),
#  ('free', 'VERB', 'free'),
#  ('people', 'NOUN', 'people'),
#  ('higher', 'ADJ', 'high'),
#  ('order', 'NOUN', 'order'),
#  ('work', 'NOUN', 'work'),
#  ('taking', 'VERB', 'take'),
#  ('repetitive', 'ADJ', 'repetitive'),
#  ('potentially', 'ADV', 'potentially'),
#  ('dangerous', 'ADJ', 'dangerous'),
#  ('jobs', 'NOUN', 'job'),
#  ('Hospitals', 'PROPN', 'Hospitals'),
#  ('health', 'NOUN', 'health'),
#  ('insurers', 'NOUN', 'insurer'),
#  ('starting', 'VERB', 'start'),
#  ('deploy', 'VERB', 'deploy'),
#  ('AI', 'PROPN', 'AI'),
#  ('widely', 'ADV', 'widely'),
#  ('big', 'ADJ', 'big'),
#  ('successes', 'NOUN', 'success'),
#  ('elusive', 'ADJ', 'elusive'),
#  ('contrast', 'NOUN', 'contrast'),
#  ('financial', 'ADJ', 'financial'),
#  ('services', 'NOUN', 'service'),
#  ('business', 'NOUN', 'business'),
#  ('ripe', 'ADJ', 'ripe'),
#  ('disruption', 'NOUN', 'disruption'),
#  ('AI', 'PROPN', 'AI'),
#  ('Lenders', 'NOUN', 'lender'),
#  ('massive', 'ADJ', 'massive'),
#  ('amounts', 'NOUN', 'amount'),
#  ('data', 'NOUN', 'datum'),
#  ('potential', 'NOUN', 'potential'),
#  ('free', 'VERB', 'free'),
#  ('billions', 'NOUN', 'billion'),
#  ('cash', 'NOUN', 'cash'),
#  ('flow', 'NOUN', 'flow'),
#  ('finding', 'VERB', 'find'),
#  ('new', 'ADJ', 'new'),
#  ('efficiencies', 'NOUN', 'efficiency'),
#  ('applications', 'NOUN', 'application'),
#  ('example', 'NOUN', 'example'),
#  ('help', 'VERB', 'help'),
#  ('bankers', 'NOUN', 'banker'),
#  ('smarter', 'ADJ', 'smart'),
#  ('lending', 'NOUN', 'lending'),
#  ('decisions', 'NOUN', 'decision'),
#  ('create', 'VERB', 'create'),
#  ('new', 'ADJ', 'new'),
#  ('revenue', 'NOUN', 'revenue'),
#  ('opportunities', 'NOUN', 'opportunity'),
#  ('offering', 'VERB', 'offer'),
#  ('customers', 'NOUN', 'customer'),
#  ('better', 'ADV', 'better'),
#  ('tailored', 'VERB', 'tailor'),
#  ('products', 'NOUN', 'product'),
#  ('said', 'VERB', 'say'),
#  ('guideposts', 'NOUN', 'guidepost'),
#  ('board', 'NOUN', 'board'),
#  ('members', 'NOUN', 'member'),
#  ('industry', 'NOUN', 'industry'),
#  ('use', 'VERB', 'use'),
#  ('orient', 'VERB', 'orient'),
#  ('begin', 'VERB', 'begin'),
#  ('journey', 'NOUN', 'journey'),
#  ('’s', 'PROPN', '’s'),
#  ('math', 'NOUN', 'math'),
#  ('magic', 'ADJ', 'magic'),
#  ('Boards', 'PROPN', 'Boards'),
#  ('n’t', 'ADV', 'not'),
#  ('intimidated', 'VERB', 'intimidate'),
#  ('AI', 'PROPN', 'AI'),
#  ('.', 'PROPN', '.'),
#  ('Members', 'NOUN', 'member'),
#  ('n’t', 'ADV', 'not'),
#  ('need', 'VERB', 'need'),
#  ('degrees', 'NOUN', 'degree'),
#  ('computer', 'NOUN', 'computer'),
#  ('engineering', 'NOUN', 'engineering'),
#  ('understand', 'VERB', 'understand'),
#  ('technology', 'NOUN', 'technology'),
#  ('AI', 'PROPN', 'AI'),
#  ('like', 'ADP', 'like'),
#  ('n’t', 'ADV', 'not'),
#  ('need', 'VERB', 'need'),
#  ('CPAs', 'NOUN', 'cpa'),
#  ('understand', 'VERB', 'understand'),
#  ('company', 'NOUN', 'company'),
#  ('’s', 'PROPN', '’s'),
#  ('balance', 'NOUN', 'balance'),
#  ('sheet', 'NOUN', 'sheet'),
#  ('good', 'ADJ', 'good'),
#  ('use', 'NOUN', 'use'),
#  ('ML', 'PROPN', 'ML'),
#  ('AI', 'PROPN', 'AI'),
#  ('going', 'VERB', 'go'),
#  ('outgrowth', 'NOUN', 'outgrowth'),
#  ('company', 'NOUN', 'company'),
#  ('kind', 'NOUN', 'kind'),
#  ('universal', 'ADJ', 'universal'),
#  ('knowing', 'VERB', 'know'),
#  ('Skynet', 'PROPN', 'Skynet'),
#  ('type', 'NOUN', 'type'),
#  ('AI', 'PROPN', 'AI'),
#  ('.', 'PROPN', '.'),
#  ('Keeping', 'VERB', 'keep'),
#  ('perspective', 'NOUN', 'perspective'),
#  ('forefront', 'NOUN', 'forefront'),
#  ('gaining', 'VERB', 'gain'),
#  ('basic', 'ADJ', 'basic'),
#  ('understanding', 'NOUN', 'understanding'),
#  ('AI', 'PROPN', 'AI'),
#  ('help', 'VERB', 'help'),
#  ('boards', 'NOUN', 'board'),
#  ('better', 'ADV', 'better'),
#  ('decide', 'VERB', 'decide'),
#  ('direct', 'VERB', 'direct'),
#  ('AI', 'PROPN', 'AI'),
#  ('use', 'NOUN', 'use'),
#  ('run', 'VERB', 'run'),
#  ('AI', 'PROPN', 'AI'),
#  ('projects', 'NOUN', 'project'),
#  ('easily', 'ADV', 'easily'),
#  ('understood', 'VERB', 'understand'),
#  ('evaluating', 'VERB', 'evaluate'),
#  ('project', 'NOUN', 'project'),
#  ('right', 'ADJ', 'right'),
#  ('company', 'NOUN', 'company'),
#  ('boards', 'NOUN', 'board'),
#  ('feel', 'VERB', 'feel'),
#  ('confident', 'ADJ', 'confident'),
#  ('n’t', 'ADV', 'not'),
#  ('sense', 'NOUN', 'sense'),
#  ('best', 'ADV', 'best'),
#  ('run', 'VERB', 'run'),
#  ('AI', 'PROPN', 'AI'),
#  ('projects', 'NOUN', 'project'),
#  ('explainable', 'ADJ', 'explainable'),
#  ('plain', 'ADJ', 'plain'),
#  ('English', 'PROPN', 'English'),
#  ('clear', 'ADJ', 'clear'),
#  ('real', 'ADJ', 'real'),
#  ('groups', 'NOUN', 'group'),
#  ('people', 'NOUN', 'people'),
#  ('employees', 'NOUN', 'employee'),
#  ('customers', 'NOUN', 'customer'),
#  ('management', 'NOUN', 'management'),
#  ('affected', 'VERB', 'affect'),
#  ('vendor', 'NOUN', 'vendor'),
#  ('internal', 'ADJ', 'internal'),
#  ('team', 'NOUN', 'team'),
#  ('n’t', 'ADV', 'not'),
#  ('explain', 'VERB', 'explain'),
#  ('AI', 'PROPN', 'AI'),
#  ('project', 'NOUN', 'project'),
#  ('works', 'VERB', 'work'),
#  ('right', 'ADJ', 'right'),
#  ('fit', 'NOUN', 'fit'),
#  ('company', 'NOUN', 'company'),
#  ('unique', 'ADJ', 'unique'),
#  ('ML', 'PROPN', 'ML'),
#  ('true', 'ADJ', 'true'),
#  ('ERP', 'PROPN', 'ERP'),
#  ('implementations', 'NOUN', 'implementation'),
#  ('—', 'X', '—'),
#  ('ML', 'PROPN', 'ML'),
#  ('moving', 'VERB', 'move'),
#  ('quickly', 'ADV', 'quickly'),
#  ('corporate', 'ADJ', 'corporate'),
#  ('world', 'NOUN', 'world'),
#  ('ERPs', 'NOUN', 'erp'),
#  ('example', 'NOUN', 'example'),
#  ('presented', 'VERB', 'present'),
#  ('ML', 'NOUN', 'ml'),
#  ('underwriting', 'NOUN', 'underwriting'),
#  ('project', 'NOUN', 'project'),
#  ('board', 'NOUN', 'board'),
#  ('credit', 'NOUN', 'credit'),
#  ('card', 'NOUN', 'card'),
#  ('issuer', 'NOUN', 'issuer'),
#  ('started', 'VERB', 'start'),
#  ('economic', 'ADJ', 'economic'),
#  ('impact', 'NOUN', 'impact'),
#  ('business', 'NOUN', 'business'),
#  ('timeframe', 'NOUN', 'timeframe'),
#  ('delivery', 'NOUN', 'delivery'),
#  ('roadblocks', 'NOUN', 'roadblock'),
#  ('compliance', 'NOUN', 'compliance'),
#  ('need', 'VERB', 'need'),
#  ('involved', 'ADJ', 'involved'),
#  ('n’t', 'ADV', 'not'),
#  ('creepy', 'ADJ', 'creepy'),
#  ('value', 'NOUN', 'value'),
#  ('data', 'NOUN', 'datum'),
#  ('companies', 'NOUN', 'company'),
#  ('assume', 'VERB', 'assume'),
#  ('order', 'NOUN', 'order'),
#  ('AI', 'PROPN', 'AI'),
#  ('need', 'VERB', 'need'),
#  ('like', 'ADP', 'like'),
#  ('Facebook', 'PROPN', 'Facebook'),
#  ('Google', 'PROPN', 'Google'),
#  ('pull', 'VERB', 'pull'),
#  ('bit', 'NOUN', 'bit'),
#  ('data', 'NOUN', 'datum'),
#  ('find', 'VERB', 'find'),
#  ('creepy', 'ADJ', 'creepy'),
#  ('fast', 'ADV', 'fast'),
#  ('usually', 'ADV', 'usually'),
#  ('’s', 'PROPN', '’s'),
#  ('need', 'NOUN', 'need'),
#  ('level', 'NOUN', 'level'),
#  ('data', 'NOUN', 'datum'),
#  ('work', 'NOUN', 'work'),
#  ('developing', 'VERB', 'develop'),
#  ('machine', 'NOUN', 'machine'),
#  ('learning', 'NOUN', 'learning'),
#  ('based', 'VERB', 'base'),
#  ('credit', 'NOUN', 'credit'),
#  ('underwriting', 'NOUN', 'underwriting'),
#  ('models', 'NOUN', 'model'),
#  ('banks', 'NOUN', 'bank'),
#  ('lenders', 'NOUN', 'lender'),
#  ('shown', 'VERB', 'show'),
#  ('social', 'ADJ', 'social'),
#  ('media', 'NOUN', 'medium'),
#  ('data', 'NOUN', 'datum'),
#  ('n’t', 'ADV', 'not'),
#  ('provide', 'VERB', 'provide'),
#  ('strong', 'ADJ', 'strong'),
#  ('signals', 'NOUN', 'signal'),
#  ('companies', 'NOUN', 'company'),
#  ('sitting', 'VERB', 'sit'),
#  ('ton', 'NOUN', 'ton'),
#  ('pretty', 'ADJ', 'pretty'),
#  ('banal', 'ADJ', 'banal'),
#  ('data', 'NOUN', 'datum'),
#  ('’s', 'PROPN', '’s'),
#  ('signal', 'NOUN', 'signal'),
#  ('insights', 'NOUN', 'insight'),
#  ('unlocked', 'ADJ', 'unlocked'),
#  ('ML', 'PROPN', 'ML'),
#  ('AI', 'PROPN', 'AI'),
#  ('operating', 'VERB', 'operate'),
#  ('expense', 'NOUN', 'expense'),
#  ('capital', 'NOUN', 'capital'),
#  ('investment', 'NOUN', 'investment'),
#  ('management', 'NOUN', 'management'),
#  ('’s', 'PROPN', '’s'),
#  ('plan', 'NOUN', 'plan'),
#  ('getting', 'VERB', 'get'),
#  ('AI', 'PROPN', 'AI'),
#  ('bandwagon', 'NOUN', 'bandwagon'),
#  ('revolves', 'VERB', 'revolve'),
#  ('big', 'ADJ', 'big'),
#  ('time', 'NOUN', 'time'),
#  ('investment', 'NOUN', 'investment'),
#  ('chances', 'NOUN', 'chance'),
#  ('going', 'VERB', 'go'),
#  ('wrong', 'ADJ', 'wrong'),
#  ('AI', 'PROPN', 'AI'),
#  ('potential', 'NOUN', 'potential'),
#  ('enhance', 'VERB', 'enhance'),
#  ('line', 'NOUN', 'line'),
#  ('boosting', 'VERB', 'boost'),
#  ('revenue', 'NOUN', 'revenue'),
#  ('cutting', 'NOUN', 'cutting'),
#  ('costs', 'NOUN', 'cost'),
#  ('budget', 'NOUN', 'budget'),
#  ('needs', 'VERB', 'need'),
#  ('aside', 'ADV', 'aside'),
#  ('ensure', 'VERB', 'ensure'),
#  ('algorithms', 'NOUN', 'algorithm'),
#  ('models', 'NOUN', 'model'),
#  ('functioning', 'VERB', 'function'),
#  ('properly', 'ADV', 'properly'),
#  ('rebuilt', 'VERB', 'rebuild'),
#  ('refit', 'VERB', 'refit'),
#  ('macro', 'ADJ', 'macro'),
#  ('factors', 'NOUN', 'factor'),
#  ('change', 'NOUN', 'change'),
#  ('new', 'ADJ', 'new'),
#  ('sources', 'NOUN', 'source'),
#  ('data', 'NOUN', 'datum'),
#  ('emerge', 'NOUN', 'emerge'),
#  ('Think', 'VERB', 'think'),
#  ('AI', 'PROPN', 'AI'),
#  ('Formula', 'PROPN', 'Formula'),
#  ('1', 'NUM', '1'),
#  ('race', 'NOUN', 'race'),
#  ('car', 'NOUN', 'car'),
#  ('performs', 'VERB', 'perform'),
#  ('best', 'ADV', 'best'),
#  ('support', 'NOUN', 'support'),
#  ('team', 'NOUN', 'team'),
#  ('real', 'ADJ', 'real'),
#  ('time', 'NOUN', 'time'),
#  ('view', 'NOUN', 'view'),
#  ('vehicle', 'NOUN', 'vehicle'),
#  ('’s', 'PROPN', '’s'),
#  ('health', 'NOUN', 'health'),
#  ('’s', 'VERB', '’s'),
#  ('zipping', 'VERB', 'zip'),
#  ('track', 'NOUN', 'track'),
#  ('Widespread', 'ADJ', 'widespread'),
#  ('adoption', 'NOUN', 'adoption'),
#  ('AI', 'PROPN', 'AI'),
#  ('business', 'NOUN', 'business'),
#  ('infancy', 'NOUN', 'infancy'),
#  ('Boards', 'PROPN', 'Boards'),
#  ('fail', 'VERB', 'fail'),
#  ('trend', 'NOUN', 'trend'),
#  ('pay', 'VERB', 'pay'),
#  ('price', 'NOUN', 'price'),
#  ('Douglas', 'PROPN', 'Douglas'),
#  ('Merrill', 'PROPN', 'Merrill'),
#  ('CEO', 'NOUN', 'ceo'),
#  ('founder', 'NOUN', 'founder'),
#  ('ZestFinance', 'PROPN', 'ZestFinance'),
#  ('Los', 'PROPN', 'Los'),
#  ('Angeles', 'PROPN', 'Angeles'),
#  ('based', 'VERB', 'base'),
#  ('financial', 'ADJ', 'financial'),
#  ('services', 'NOUN', 'service'),
#  ('technology', 'NOUN', 'technology'),
#  ('company', 'NOUN', 'company'),
#  ('previously', 'ADV', 'previously'),
#  ('CIO', 'PROPN', 'CIO'),
#  ('VP', 'PROPN', 'VP'),
#  ('Engineering', 'PROPN', 'Engineering'),
#  ('Google', 'PROPN', 'Google'),
#  ('article', 'NOUN', 'article'),
#  ('BOARDS', 'PROPN', 'BOARDS'),
#  (' ', 'SPACE', ' '),
#  ('Follow', 'VERB', 'follow'),
#  ('topic', 'NOUN', 'topic'),
#  (' ', 'SPACE', ' '),
#  ('Following', 'VERB', 'follow'),
#  ('Related', 'PROPN', 'Related'),
#  ('Topics', 'PROPN', 'Topics'),
#  ('Technology', 'PROPN', 'Technology'),
#  ('Analytics', 'PROPN', 'Analytics'),
#  ('Loading', 'PROPN', 'Loading'),
#  ('Loading', 'NOUN', 'loading'),
#  ('Partner', 'PROPN', 'Partner'),
#  ('Center', 'PROPN', 'Center'),
#  ('Latest', 'PROPN', 'Latest'),
#  ('Magazine', 'PROPN', 'Magazine'),
#  ('Popular', 'PROPN', 'Popular'),
#  ('Topics', 'PROPN', 'Topics'),
#  ('Podcasts', 'PROPN', 'Podcasts'),
#  ('Video', 'PROPN', 'Video'),
#  ('Store', 'PROPN', 'Store'),
#  ('Big', 'PROPN', 'Big'),
#  ('Idea', 'PROPN', 'Idea'),
#  ('Visual', 'PROPN', 'Visual'),
#  ('Library', 'PROPN', 'Library'),
#  ('Reading', 'PROPN', 'Reading'),
#  ('Lists', 'PROPN', 'Lists'),
#  ('Case', 'PROPN', 'Case'),
#  ('Selections', 'PROPN', 'Selections'),
#  ('                                                                        ',
#   'SPACE',
#   '                                                                        '),
#  ('Subscribe', 'PROPN', 'Subscribe'),
#  ('                                                                                     ',
#   'SPACE',
#   '                                                                                     '),
#  ('EXPLORE', 'PROPN', 'EXPLORE'),
#  ('HBR', 'PROPN', 'HBR'),
#  ('                                 ',
#   'SPACE',
#   '                                 '),
#  ('Latest', 'ADJ', 'late'),
#  ('        ', 'SPACE', '        '),
#  ('Popular', 'PROPN', 'Popular'),
#  ('        ', 'SPACE', '        '),
#  ('Topics', 'PROPN', 'Topics'),
#  ('        ', 'SPACE', '        '),
#  ('Magazine', 'PROPN', 'Magazine'),
#  ('Archive', 'PROPN', 'Archive'),
#  ('        ', 'SPACE', '        '),
#  ('Big', 'PROPN', 'Big'),
#  ('Idea', 'PROPN', 'Idea'),
#  ('        ', 'SPACE', '        '),
#  ('Reading', 'VERB', 'read'),
#  ('Lists', 'PROPN', 'Lists'),
#  ('        ', 'SPACE', '        '),
#  ('Video', 'PROPN', 'Video'),
#  ('        ', 'SPACE', '        '),
#  ('Podcasts', 'PROPN', 'Podcasts'),
#  ('        ', 'SPACE', '        '),
#  ('Webinars', 'PROPN', 'Webinars'),
#  ('        ', 'SPACE', '        '),
#  ('Visual', 'ADJ', 'visual'),
#  ('Library', 'PROPN', 'Library'),
#  ('        ', 'SPACE', '        '),
#  ('Library', 'PROPN', 'Library'),
#  ('        ', 'SPACE', '        '),
#  ('Newsletters', 'PROPN', 'Newsletters'),
#  ('        ', 'SPACE', '        '),
#  ('HBR', 'PROPN', 'HBR'),
#  ('Ascend', 'PROPN', 'Ascend'),
#  ('                                      ',
#   'SPACE',
#   '                                      '),
#  ('HBR', 'PROPN', 'HBR'),
#  ('STORE', 'PROPN', 'STORE'),
#  ('                                 ',
#   'SPACE',
#   '                                 '),
#  ('Article', 'PROPN', 'Article'),
#  ('Reprints', 'PROPN', 'Reprints'),
#  ('        ', 'SPACE', '        '),
#  ('Books', 'PROPN', 'Books'),
#  ('        ', 'SPACE', '        '),
#  ('Cases', 'NOUN', 'case'),
#  ('        ', 'SPACE', '        '),
#  ('Collections', 'PROPN', 'Collections'),
#  ('        ', 'SPACE', '        '),
#  ('Magazine', 'PROPN', 'Magazine'),
#  ('Issues', 'PROPN', 'Issues'),
#  ('        ', 'SPACE', '        '),
#  ('HBR', 'PROPN', 'HBR'),
#  ('Guide', 'PROPN', 'Guide'),
#  ('Series', 'PROPN', 'Series'),
#  ('        ', 'SPACE', '        '),
#  ('HBR', 'PROPN', 'HBR'),
#  ('20-Minute', 'NUM', '20-minute'),
#  ('Managers', 'NOUN', 'manager'),
#  ('        ', 'SPACE', '        '),
#  ('HBR', 'PROPN', 'HBR'),
#  ('Reads', 'PROPN', 'Reads'),
#  ('        ', 'SPACE', '        '),
#  ('Tools', 'PROPN', 'Tools'),
#  ('                                      ',
#   'SPACE',
#   '                                      '),
#  ('HBR', 'PROPN', 'HBR'),
#  ('                                 ',
#   'SPACE',
#   '                                 '),
#  ('Contact', 'PROPN', 'Contact'),
#  ('        ', 'SPACE', '        '),
#  ('Advertise', 'PROPN', 'Advertise'),
#  ('        ', 'SPACE', '        '),
#  ('Information', 'PROPN', 'Information'),
#  ('Booksellers', 'PROPN', 'Booksellers'),
#  ('/', 'SYM', '/'),
#  ('Retailers', 'PROPN', 'Retailers'),
#  ('        ', 'SPACE', '        '),
#  ('Masthead', 'PROPN', 'Masthead'),
#  ('        ', 'SPACE', '        '),
#  ('Global', 'PROPN', 'Global'),
#  ('Editions', 'PROPN', 'Editions'),
#  ('        ', 'SPACE', '        '),
#  ('Media', 'PROPN', 'Media'),
#  ('Inquiries', 'PROPN', 'Inquiries'),
#  ('        ', 'SPACE', '        '),
#  ('Guidelines', 'PROPN', 'Guidelines'),
#  ('Authors', 'NOUN', 'author'),
#  ('        ', 'SPACE', '        '),
#  ('HBR', 'PROPN', 'HBR'),
#  ('Analytic', 'PROPN', 'Analytic'),
#  ('Services', 'PROPN', 'Services'),
#  ('                                      ',
#   'SPACE',
#   '                                      '),
#  ('HBR', 'PROPN', 'HBR'),
#  ('SUBSCRIBER', 'PROPN', 'SUBSCRIBER'),
#  ('ASSISTANCE', 'PROPN', 'ASSISTANCE'),
#  ('                                           ',
#   'SPACE',
#   '                                           '),
#  ('Subscribe', 'PROPN', 'Subscribe'),
#  ('                           ', 'SPACE', '                           '),
#  ('Subscriber', 'PROPN', 'Subscriber'),
#  ('Help', 'PROPN', 'Help'),
#  ('                 ', 'SPACE', '                 '),
#  ('U.S./Canada', 'NOUN', 'u.s./canada'),
#  ('        ', 'SPACE', '        '),
#  ('800.274.3214', 'NUM', '800.274.3214'),
#  ('                 ', 'SPACE', '                 '),
#  ('harvard@cdsfulfillment.com', 'X', 'harvard@cdsfulfillment.com'),
#  ('                 ', 'SPACE', '                 '),
#  ('hbr.org/subscriberservices', 'PROPN', 'hbr.org/subscriberservices'),
#  ('        ', 'SPACE', '        '),
#  ('International', 'PROPN', 'International'),
#  ('        ', 'SPACE', '        '),
#  ('+44.1858.438.412', 'PROPN', '+44.1858.438.412'),
#  ('                 ', 'SPACE', '                 '),
#  ('Asia', 'PROPN', 'Asia'),
#  ('Pacific', 'PROPN', 'Pacific'),
#  ('+612.8296.5401', 'PROPN', '+612.8296.5401'),
#  ('                 ', 'SPACE', '                 '),
#  ('hbr@subscription.co.uk', 'VERB', 'hbr@subscription.co.uk'),
#  ('                 ', 'SPACE', '                 '),
#  ('subscription.co.uk/hbr/help', 'NUM', 'subscription.co.uk/hbr/help'),
#  ('                                      ',
#   'SPACE',
#   '                                      '),
#  ('HBR.ORG', 'PROPN', 'HBR.ORG'),
#  ('CUSTOMER', 'PROPN', 'CUSTOMER'),
#  ('ASSISTANCE', 'PROPN', 'ASSISTANCE'),
#  ('                                 ',
#   'SPACE',
#   '                                 '),
#  ('Help', 'PROPN', 'Help'),
#  ('Center', 'PROPN', 'Center'),
#  ('                 ', 'SPACE', '                 '),
#  ('U.S./Canada', 'NOUN', 'u.s./canada'),
#  ('        ', 'SPACE', '        '),
#  ('800.988.0886', 'NUM', '800.988.0886'),
#  ('                 ', 'SPACE', '                 '),
#  ('International', 'PROPN', 'International'),
#  ('        ', 'SPACE', '        '),
#  ('617.783.7500', 'NUM', '617.783.7500'),
#  ('        ', 'SPACE', '        '),
#  ('Email', 'NOUN', 'email'),
#  ('        ', 'SPACE', '        '),
#  ('customerservice@harvardbusiness.org',
#   'PROPN',
#   'customerservice@harvardbusiness.org'),
#  ('        ', 'SPACE', '        '),
#  ('Copyright', 'PROPN', 'Copyright'),
#  ('Permissions', 'PROPN', 'Permissions'),
#  ('                                      ',
#   'SPACE',
#   '                                      '),
#  ('FOLLOW', 'PROPN', 'FOLLOW'),
#  ('HBR', 'PROPN', 'HBR'),
#  ('                         ', 'SPACE', '                         '),
#  ('Facebook', 'PROPN', 'Facebook'),
#  ('         ', 'SPACE', '         '),
#  ('Twitter', 'PROPN', 'Twitter'),
#  ('         ', 'SPACE', '         '),
#  ('LinkedIn', 'PROPN', 'LinkedIn'),
#  ('         ', 'SPACE', '         '),
#  ('Instagram', 'PROPN', 'Instagram'),
#  ('         ', 'SPACE', '         '),
#  ('Newsreader', 'PROPN', 'Newsreader'),
#  ('                                                                                ',
#   'SPACE',
#   '                                                                                '),
#  ('      ', 'SPACE', '      '),
#  ('Careers', 'PROPN', 'Careers'),
#  ('      ', 'SPACE', '      '),
#  ('Privacy', 'PROPN', 'Privacy'),
#  ('Policy', 'PROPN', 'Policy'),
#  ('      ', 'SPACE', '      '),
#  ('Copyright', 'PROPN', 'Copyright'),
#  ('Information', 'PROPN', 'Information'),
#  ('      ', 'SPACE', '      '),
#  ('Trademark', 'PROPN', 'Trademark'),
#  ('Policy', 'PROPN', 'Policy'),
#  ('          ', 'SPACE', '          '),
#  ('Harvard', 'PROPN', 'Harvard'),
#  ('Business', 'PROPN', 'Business'),
#  ('Publishing', 'PROPN', 'Publishing'),
#  ('            ', 'SPACE', '            '),
#  ('Higher', 'PROPN', 'Higher'),
#  ('Education', 'PROPN', 'Education'),
#  ('      ', 'SPACE', '      '),
#  ('Corporate', 'PROPN', 'Corporate'),
#  ('Learning', 'PROPN', 'Learning'),
#  ('      ', 'SPACE', '      '),
#  ('Harvard', 'PROPN', 'Harvard'),
#  ('Business', 'PROPN', 'Business'),
#  ('Review', 'PROPN', 'Review'),
#  ('      ', 'SPACE', '      '),
#  ('Harvard', 'PROPN', 'Harvard'),
#  ('Business', 'PROPN', 'Business'),
#  ('School', 'PROPN', 'School'),
#  ('           ', 'SPACE', '           '),
#  ('Copyright', 'PROPN', 'Copyright'),
#  ('©', 'PROPN', '©'),
#  ('2019', 'NUM', '2019'),
#  ('Harvard', 'PROPN', 'Harvard'),
#  ('Business', 'PROPN', 'Business'),
#  ('School', 'PROPN', 'School'),
#  ('Publishing', 'PROPN', 'Publishing'),
#  ('rights', 'NOUN', 'right'),
#  ('reserved', 'VERB', 'reserve'),
#  ('Harvard', 'PROPN', 'Harvard'),
#  ('Business', 'PROPN', 'Business'),
#  ('Publishing', 'PROPN', 'Publishing'),
#  ('affiliate', 'NOUN', 'affiliate'),
#  ('Harvard', 'PROPN', 'Harvard'),
#  ('Business', 'PROPN', 'Business'),
#  ('School', 'PROPN', 'School'),
#  ('                             ', 'SPACE', '                             ')]

# %%
#Final Dictionnary to upgrade
dict([(str(x), x.label_) for x in nlp(str(sentences)).ents])
# Out:
# {'2/3': 'CARDINAL',
#  'Register': 'PERSON',
#  'Subscribe Sign': 'PERSON',
#  'HBR': 'ORG',
#  'The Magazine, Most Popular Podcasts Video Store': 'ORG',
#  'Managing, Yourself Leadership Strategy Managing Teams Gender Innovation Work-life': 'ORG',
#  'Balance All Topics': 'ORG',
#  'Subscribers': 'PERSON',
#  'The Big Idea Visual Library Reading Lists Case': 'ORG',
#  'Sign': 'ORG',
#  'All Topics': 'ORG',
#  'The Big Idea Visual Library Reading Lists Case Selections': 'ORG',
#  'Library Account Settings Log Out Sign': 'PERSON',
#  'Guest User  ': 'PERSON',
#  'Boards': 'GPE',
#  'Boards Need': 'WORK_OF_ART',
#  'Douglas Merrill': 'PERSON',
#  'May 24, 2019  ': 'DATE',
#  'Summary Full Text  ': 'PERSON',
#  'Save  Share  ': 'PERSON',
#  'Comment  ': 'PERSON',
#  'Text Size  ': 'PERSON',
#  'Print Loading...': 'PERSON',
#  'Summary': 'PERSON',
#  'AI': 'ORG',
#  'C. J. Burton': 'PERSON',
#  'Getty Images': 'PERSON',
#  'More than half': 'CARDINAL',
#  'Gartner CIO Survey': 'EVENT',
#  'the end of 2020': 'DATE',
#  '14%': 'PERCENT',
#  'today': 'DATE',
#  'NewVantage Partners': 'ORG',
#  '75%': 'PERCENT',
#  'Insight Center                  ': 'ORG',
#  'half': 'CARDINAL',
#  'billions': 'CARDINAL',
#  'four': 'CARDINAL',
#  'ML': 'ORG',
#  'English': 'LANGUAGE',
#  'ERP': 'ORG',
#  'one': 'CARDINAL',
#  'Facebook': 'PERSON',
#  'Google': 'ORG',
#  'ZestFinance': 'ORG',
#  'Los Angeles': 'GPE',
#  'CIO': 'ORG',
#  'VP of Engineering at Google': 'ORG',
#  'Partner Center': 'ORG',
#  'Subscribe': 'PERSON',
#  'Webinars': 'PRODUCT',
#  'Visual Library         ': 'PERSON',
#  '20-Minute': 'CARDINAL',
#  'HBR Must': 'ORG',
#  'Reads': 'ORG',
#  'Contact Us         ': 'PERSON',
#  'Us': 'GPE',
#  'Booksellers/Retailers         Masthead         Global Editions': 'ORG',
#  'Media Inquiries': 'ORG',
#  'HBR Analytic Services': 'ORG',
#  'Asia Pacific': 'ORG',
#  'Help Center': 'ORG',
#  'LinkedIn': 'PERSON',
#  'Instagram': 'NORP',
#  'Privacy Policy       ': 'PERSON',
#  'Copyright Information       ': 'ORG',
#  'Trademark Policy': 'PERSON',
#  'Harvard Business Publishing': 'ORG',
#  'Higher Education       ': 'ORG',
#  'Harvard Business Review       ': 'ORG',
#  'Harvard Business School': 'ORG',
#  'Copyright': 'ORG',
#  '2019': 'DATE',
#  'Harvard Business School Publishing': 'ORG'}

# %%
pprint([(X.text, X.label_) for X in article.ents])
# Out:
# [('Boards Need', 'ORG'),
#  ('Know', 'PERSON'),
#  ('Register', 'PERSON'),
#  ('Subscribe Sign', 'PERSON'),
#  ('Balance All Topics', 'ORG'),
#  ('Library Account Settings Log Out Sign', 'PERSON'),
#  ('Reading List Reading Lists Boards', 'WORK_OF_ART'),
#  ('Douglas Merrill', 'PERSON'),
#  ('May 24, 2019  ', 'DATE'),
#  ('Text  ', 'PERSON'),
#  ('Summary', 'PERSON'),
#  ('Boards', 'GPE'),
#  ('C. J. Burton', 'PERSON'),
#  ('Getty Images', 'PERSON'),
#  ('More than half', 'CARDINAL'),
#  ('Gartner CIO Survey', 'EVENT'),
#  ('the end of 2020', 'DATE'),
#  ('14%', 'PERCENT'),
#  ('today', 'DATE'),
#  ('NewVantage Partners', 'ORG'),
#  ('75%', 'PERCENT'),
#  ('half', 'CARDINAL'),
#  ('billions', 'CARDINAL'),
#  ('four', 'CARDINAL'),
#  ('ML', 'ORG'),
#  ('AI', 'ORG'),
#  ('AI', 'ORG'),
#  ('English', 'LANGUAGE'),
#  ('ERP', 'ORG'),
#  ('ML', 'ORG'),
#  ('ML', 'ORG'),
#  ('one', 'CARDINAL'),
#  ('Facebook', 'PERSON'),
#  ('Google', 'ORG'),
#  ('ML', 'ORG'),
#  ('’s', 'ORG'),
#  ('AI', 'ORG'),
#  ('one', 'CARDINAL'),
#  ('Formula 1', 'LAW'),
#  ('’s', 'GPE'),
#  ('Douglas Merrill', 'PERSON'),
#  ('ZestFinance', 'ORG'),
#  ('Los Angeles', 'GPE'),
#  ('CIO', 'ORG'),
#  ('VP of Engineering at Google', 'ORG'),
#  ('Partner Center', 'ORG'),
#  ('Subscribe', 'PERSON'),
#  ('Visual Library         ', 'PERSON'),
#  ('Booksellers/Retailers         Masthead         Global Editions', 'ORG'),
#  ('Media Inquiries', 'ORG'),
#  ('HBR Analytic Services', 'ORG'),
#  ('Subscribe', 'PERSON'),
#  ('Asia Pacific', 'ORG'),
#  ('617.783.7500', 'CARDINAL'),
#  ('Copyright Permissions', 'PRODUCT'),
#  ('Facebook', 'PERSON'),
#  ('LinkedIn', 'PERSON'),
#  ('Instagram', 'NORP'),
#  ('Us', 'GPE'),
#  ('Harvard Business Publishing', 'ORG'),
#  ('Harvard Business Review', 'ORG'),
#  ('Harvard Business School', 'ORG'),
#  ('2019', 'DATE'),
#  ('Harvard Business School Publishing', 'ORG'),
#  ('Harvard Business Publishing', 'ORG'),
#  ('Harvard Business School', 'ORG')]
